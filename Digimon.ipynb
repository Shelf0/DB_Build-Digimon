# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests 
import os

import json
#from config import api_key



# Import API key
#from api_keys import g_key
#ajayakv-rest-countries-v1.p.rapidapi.com.configure(api_key=rapid_api_key)

# %%
#countries_df = pd.read_csv("C:/Users/19739/Desktop/New folder/Project_2/Resources/Countries.csv")
#countries_df


df = pd.read_csv("C:/Users/19739/Desktop/New folder/Project_3/Resources/DigiDB_digimonlist.csv")
df
# Out:
#      Number            Digimon Stage     Type Attribute  Memory  Equip Slots  \
# 0         1            Kuramon  Baby     Free   Neutral       2            0
# 1         2            Pabumon  Baby     Free   Neutral       2            0
# 2         3            Punimon  Baby     Free   Neutral       2            0
# 3         4            Botamon  Baby     Free   Neutral       2            0
# 4         5            Poyomon  Baby     Free   Neutral       2            0
# ..      ...                ...   ...      ...       ...     ...          ...
# 244     245         Valkyrimon  Mega     Free      Wind      18            3
# 245     246    ShineGreymon BM  Mega  Vaccine      Fire      22            2
# 246     247  MirageGaogamon BM  Mega     Data     Light      20            2
# 247     248         Ravemon BM  Mega  Vaccine      Wind      20            2
# 248     249         Rosemon BM  Mega     Data     Plant      20            2
#
# ...

# %%
moves_df = pd.read_csv("C:/Users/19739/Desktop/New folder/Project_3/Resources/DigiDB_movelist.csv")
moves_df
# Out:
#                 Move  SP Cost      Type  Power Attribute Inheritable  \
# 0      Wolkenapalm I        3  Physical     65      Fire         Yes
# 1     Wolkenapalm II        6  Physical     85      Fire         Yes
# 2    Wolkenapalm III        9  Physical    105      Fire         Yes
# 3      Burst Flame I        3     Magic     55      Fire         Yes
# 4     Burst Flame II        6     Magic     75      Fire         Yes
# ..               ...      ...       ...    ...       ...         ...
# 382  Garuru Tomahawk       20  Physical    140   Neutral          No
# 383   Fist of Athena       50  Physical      0      Fire          No
# 384   Supreme Cannon       30     Magic    130     Water          No
# 385  Dark Prominence       30     Magic      0      Dark          No
# 386     Plasma Shoot       25  Physical     35      Fire          No
#
#                                            Description
# 0    Physical attack, 65 Fire damage to one foe. 95...
# ...

# %%
sorted_moves_df = moves_df.sort_values(by=['Attribute'])
sorted_moves_df
# Out:
#                      Move  SP Cost      Type  Power Attribute Inheritable  \
# 70   Destruction Cannon I        3  Physical     65      Dark         Yes
# 299      Demonic Disaster       25  Physical    140      Dark          No
# 324      Pandemonium Lost       25     Magic     80      Dark          No
# 235            Night Raid       15     Magic     65      Dark          No
# 237         Love Serenade       30     Magic      0      Dark          No
# ..                    ...      ...       ...    ...       ...         ...
# 53           Sonic Void I        3     Magic     55      Wind         Yes
# 52          Wind Claw III        9  Physical    105      Wind         Yes
# 51           Wind Claw II        6  Physical     85      Wind         Yes
# 58         Gale Storm III       10  Physical     75      Wind         Yes
# 243     The King of Fists       15  Physical     55      Wind          No
#
#                                            Description
# ...

# %%
n = len(pd.unique(sorted_moves_df['Attribute']))

print(n)
# Out:
# 10

# %%
#Keep Index, Country, Value exported in 2020
cleaned_df = sorted_moves_df.drop(columns=['SP Cost', 'Power', 'Inheritable','Type'])
cleaned_df

# Set new index to Attribute
#Att_df = cleaned_df.set_index("Attribute")
#Att_df




#cleaned_countries_df = cleaned_df.rename(columns={'Country': 'country'})
#print(df_new)
#alpha_countries_df = cleaned_countries_df.sort_values(by='country')
#final_countries_df = alpha_countries_df.set_index('country')

#keep move, attribute & Description
#Reset index
# Out:
#                      Move Attribute  \
# 70   Destruction Cannon I      Dark
# 299      Demonic Disaster      Dark
# 324      Pandemonium Lost      Dark
# 235            Night Raid      Dark
# 237         Love Serenade      Dark
# ..                    ...       ...
# 53           Sonic Void I      Wind
# 52          Wind Claw III      Wind
# 51           Wind Claw II      Wind
# 58         Gale Storm III      Wind
# 243     The King of Fists      Wind
#
#                                            Description
# 70   Physical attack, 65 Dark damage to one foe. 95...
# 299       Physical attack, 140 Dark damage to one foe.
# 324  Magic attack, 80 Dark damage to all foes, abso...
# 235  Magic attack, 65 Dark damage to all foes, abso...
# 237  INT-penetrating attack, Dark damage to all foe...
# ..                                                 ...
# 53   Magic attack, 55 Wind damage to one foe. 95% a...
# 52   Physical attack, 105 Wind damage to one foe. 9...
# ...

# %%
#dark_df = Att_df.loc[["Dark"], ["Attribute","Move","Description"]]
#print(dark_df)

# Filter the data so that only those sightings in the US are in a DataFrame
Dark_df = cleaned_df.loc[cleaned_df["Attribute"] == "Dark", :]
Dark_df = Better_df.set_index("Attribute")
Dark_df

#Export the Data 
Dark_df.to_csv(r'C:/Users/19739/Desktop/New folder/Project_3/Exported_Data/Dark.csv')
# Out:
#                                Move  \
# Attribute
# Dark           Destruction Cannon I
# Dark               Demonic Disaster
# Dark               Pandemonium Lost
# Dark                     Night Raid
# Dark                  Love Serenade
# Dark              Talisman of Light
# Dark                     Dark Pupil
# Dark       Unidentified Flying Kiss
# Dark                    Destruction
# Dark               Hell Crusher III
# Dark                Hell Crusher II
# Dark                 Hell Crusher I
# Dark                  Nightmare III
# Dark                   Nightmare II
# Dark                    Nightmare I
# Dark         Destruction Cannon III
# Dark          Destruction Cannon II
# Dark                  Darkness Wave
# Dark              Taizoukai Mandala
# Dark                      Megadeath
# Dark                  Double Impact
# Dark              Eternal Nightmare
# Dark               Dark Terra Force
# Dark                      Dark Roar
# ...

# %%
Dark_df = cleaned_df.loc[cleaned_df["Attribute"] == "Dark", :]
Dark_df = Better_df.set_index("Attribute")
Dark_df
